# %%
import pandas as pd
from typing import List, Dict

df = pd.read_csv("../data/base_datos.csv")
df["Nombres Estaciones"].unique()
# Out:
# array(['Cabo de San Antonio en Pinar del Río', 'Ciudad de Pinar del Río',
#        'Bahía Honda.Artemisa', 'Güira de Melena en Artemisa',
#        'Santa Fé en Isla de la Juventud', 'Güines en Mayabeque',
#        'Varadero en Matanzas', 'Jovellanos en Matanzas', 'Playa Girón en Matanzas',
#        'Ciudad de Cienfuegos', 'El Yabú en Santa Clara',
#        'Sancti Spíritus Ciudad', 'Venezuela en Ciego de Ávila',
#        'Cayo Coco en Ciego de Ávila', 'Ciudad de Camagüey',
#        'Santa Cruz del Sur en Camagüey', 'Ciudad de Las Tunas',
#        'Pedagogico de Holguín', 'Cabo Lucrecia en Holguín', 'Veguitas en Granma',
#        'Cabo Cruz en Granma', 'Pinares de Mayarí en Holguín',
#        'Universidad de Santiago de Cuba', 'Ciudad de Guantánamo',
#        'Punta de Maisí en Guantánamo', 'Casablanca en La Habana'], dtype=object)

# %%
zones = ['Cabo de San Antonio en Pinar del Río', 'Varadero en Matanzas', 'Playa Girón en Matanzas',
         'Cayo Coco en Ciego de Ávila','Cabo Lucrecia en Holguín', 'Cabo Cruz en Granma', 'Punta de Maisí en Guantánamo']

data = df[df["Nombres Estaciones"].isin(zones)].copy()
data["Zona"] = data["Nombres Estaciones"].str.split(".").str[0]
data
# Out:
#       Estación   Año  Mes  Temperatura max med  Temperatura min med  \
# 0        78310  1990    1                 27.9                 20.6
# 1        78310  1990    2                 28.0                 21.2
# 2        78310  1990    3                 28.1                 21.1
# 3        78310  1990    4                 29.5                 22.0
# 4        78310  1990    5                 30.4                 24.0
# ...        ...   ...  ...                  ...                  ...
# 9895     78369  2022    8                 31.9                 26.2
# 9896     78369  2022    9                 32.4                 24.9
# 9897     78369  2022   10                 31.5                 24.5
# 9898     78369  2022   11                 30.2                 25.6
# 9899     78369  2022   12                 28.9                 23.2
#
#       Temperatura med  Humedad Relat  Precipitaciones  \
# 0                23.7           82.0             21.7
# 1                24.2           76.0             43.7
# 2                24.2           75.0             47.3
# 3                25.3           78.0             30.1
# 4                26.8           85.0            171.0
# ...               ...            ...              ...
# 9895             29.4           73.0             21.2
# 9896             29.3           72.0             31.1
# 9897             28.2           73.0             72.6
# 9898             27.9           73.0             67.9
# 9899             26.2           68.0             26.4
#
#                      Nombres Estaciones   Latitud  Longitud     Región  \
# 0     Cabo de San Antonio en Pinar del Río  21.86307 -84.95083  Occidente
# 1     Cabo de San Antonio en Pinar del Río  21.86307 -84.95083  Occidente
# 2     Cabo de San Antonio en Pinar del Río  21.86307 -84.95083  Occidente
# 3     Cabo de San Antonio en Pinar del Río  21.86307 -84.95083  Occidente
# 4     Cabo de San Antonio en Pinar del Río  21.86307 -84.95083  Occidente
# ...                                 ...       ...       ...        ...
# 9895          Punta de Maisí en Guantánamo  20.22579 -74.15279    Oriente
# 9896          Punta de Maisí en Guantánamo  20.22579 -74.15279    Oriente
# 9897          Punta de Maisí en Guantánamo  20.22579 -74.15279    Oriente
# 9898          Punta de Maisí en Guantánamo  20.22579 -74.15279    Oriente
# 9899          Punta de Maisí en Guantánamo  20.22579 -74.15279    Oriente
#
#          Provincias                 Zona
# 0     Pinar del Río  Cabo de San Antonio
# 1     Pinar del Río  Cabo de San Antonio
# 2     Pinar del Río  Cabo de San Antonio
# 3     Pinar del Río  Cabo de San Antonio
# 4     Pinar del Río  Cabo de San Antonio
# ...             ...                  ...
# 9895     Guantánamo       Punta de Maisí
# 9896     Guantánamo       Punta de Maisí
# 9897     Guantánamo       Punta de Maisí
# 9898     Guantánamo       Punta de Maisí
# 9899     Guantánamo       Punta de Maisí
#
# [2772 rows x 14 columns]
